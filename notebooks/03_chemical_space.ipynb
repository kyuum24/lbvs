# %%
import numpy as np
import pandas as pd
from src.visualization import plot_morgan_pca, plot_morgan_umap, plot_activity_cliff_heatmap

# %%
df = pd.read_csv(
    '../data/processed/df.csv'
)

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3715 entries, 0 to 3714
# Columns: 1038 entries, MolWt to scaffold
# dtypes: float64(1037), str(1)
# memory usage: 29.6 MB

# %%
X_desc    = df.iloc[:,:12]
X_fps     = df.iloc[:,12:-2]
y         = df.pIC50  
scaffolds = df.scaffold

# %%
plot_morgan_pca(X_fps)

# %%
plot_morgan_umap(X_fp=X_fps)
# Out:
# c:\Users\elbec\anaconda3\envs\azure\Lib\site-packages\umap\umap_.py:1887: UserWarning: gradient function is not yet implemented for jaccard distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\elbec\anaconda3\envs\azure\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
plot_activity_cliff_heatmap(X_fps[:], y[:])
# Out:
# Cliff score range: 0.0 → 1.4571696297287835
